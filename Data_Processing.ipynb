# %% [markdown]
# # Load libraries, set constants

# %%
from pathlib import Path

import PyPDF2
import tabula
import re
import numpy as np
import pandas as pd

# %%
#PROCESSED_FILE_PATH_PARQUET = 'CDC_2022_BRFSS_Survey.parquet'
PROCESSED_FILE_PATH_CSV = 'CDC_2022_BRFSS_Survey.csv'

# %%
# Change the file path
#RAW_FILE_PATH = 'Raw_Survey_Data_2022/LLCP_2022.XPT'
RAW_FILE_PATH = '/home/georgematlis/AUTH/DWS/ADVANCED_TOPICS_IN_MACHINE_LEARNING/CDC-BRFSS/Raw_Survey_Data_2022/LLCP_2022.XPT'

PDF_CODEBOOK_FILE = 'Survey_Data_2022_Codebook/Survey_Data_2022_Codebook.pdf'

VARIABLE_LIST_PATH = Path('Variable_List_with_Descriptions.txt')

FINAL_FILE = 'CDC_2022_BRFSS_Survey_No_NaNs.csv'

# %% [markdown]
# ## Convert SAS to PARQUET

# %%
def sas_converter(path: str, dest_path: str, file_format: str):
    assert file_format in ['csv', 'parquet']
    
    try:
        df = pd.read_sas(path, encoding='utf-8')
    except Exception as e:
        print('Not a valid SAS file.')
        print(e)
    else:
        if file_format == 'csv':
            df.to_csv(dest_path, index=False)
        elif file_format == 'parquet':
            df.to_parquet(dest_path, index=False)

# %%
#sas_converter(path=RAW_FILE_PATH, dest_path=PROCESSED_FILE_PATH_PARQUET, file_format='parquet')
sas_converter(path=RAW_FILE_PATH, dest_path=PROCESSED_FILE_PATH_CSV, file_format='csv')

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# ## Information Extraction from CDC Codebook

# %%
def extract_text_after_keywords(pdf_path):
    with open(pdf_path, 'rb') as file:
        pdf_reader = PyPDF2.PdfReader(file)
        
        # Extract text from each page
        text = ''
        for page_number in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_number]
            text += page.extract_text()
            
    # Use regular expressions to find text after specific keywords
    label_matches = re.findall(r'Label: (.+)', text)
    sas_variable_matches = re.findall(r'SAS Variable Name: (.+)', text)
    question_matches = re.findall(r'Question: (.+)', text)
    section_matches = re.findall(r'Section Name: (.+)', text)
    
    # Extracted text after keywords
    labels = [match.strip() for match in label_matches]
    sas_variable_names = [match.strip().replace(" ","") for match in sas_variable_matches]
    questions = [match.strip() for match in question_matches]
    sections = [match.strip() for match in section_matches]

    return labels, sas_variable_names, questions, sections

# Example usage
labels, sas_variable_names, questions, sections = extract_text_after_keywords(PDF_CODEBOOK_FILE)

# %%
print("Labels:")
print(labels)

print("\nSAS Variable Names:")
print(sas_variable_names)

print("\nQuestions:")
print(questions)

print("\nSection Names:")
print(sections)
# Out:
# Labels:
# ['State FIPS Code', 'File Month', 'Interview Date', 'Interview Month', 'Interview Day', 'Interview Year', 'Final Disposition', 'Annual Sequence Number', 'Primary Sampling Unit', 'Correct telephone number?', 'Private Residence?', 'Do you live in college housing?', 'Resident of State', 'Cellular Telephone', 'Are you 18 years of age or older?', 'Are you male or female?', 'Number of Adults in Household', 'Are you male or female?', 'Number of Adult men in Household', 'Number of
# ['Record Identification', 'Record Identification', 'Record Identification', 'Record Identification', 'Record Identification', 'Record Identification', 'Record Identification', 'Record Identification', 'Record Identification', 'Land Line Introduction', 'Land Line Introduction', 'Land Line Introduction', 'Land Line Introduction', 'Land Line Introduction', 'Land Line Introduction', 'Land Line Introduction', 'Land Line Introduction', 'Land Line Introduction', 'Land Line Introduction', 'Land Line Introduction', 'Land Line Introduction', 'Cell Phone Introduction', 'Cell Phone Introduction', 'Cell Phone Introduction', 'Cell Phone Introduction', 'Cell Phone Introduction', 'Cell Phone Introduction', 'Cell Phone Introduction', 'Cell Phone Introduction', 'Cell Phone Introduction', 'Cell Phone Introduction', 'Respondent Sex', 'Health Status', 'Healthy Days', 'Healthy Days', 'Healthy Days', 'Health Care Access', 'Health Care Access', 'Health Care Access', 'Health Care Access', 'Exercise', 'Inadequate Sleep', 'Oral Health', 'Oral Health', 'Chronic Health Conditions', 'Chronic Health Conditions', 'Chronic Health Conditions', 'Chronic Health Conditions', 'Chronic Health Conditions', 'Chronic Health Conditions', 'Chronic Health Conditions', 'Chronic Health Conditions', 'Chronic Health Conditions', 'Chronic Health Conditions', 'Chronic Health Conditions', 'Chronic Health Conditions', 'Demographics', 'Demographics', 'Demographics', 'Demographics', 'Demographics', 'Demographics', 'Demographics', 'Demographics', 'Demographics', 'Demographics', 'Demographics', 'Disability', 'Disability', 'Disability', 'Disability', 'Disability', 'Disability', 'Breast and Cervical Cancer Screening', 'Breast and Cervical Cancer Screening', 'Breast and Cervical Cancer Screening', 'Breast and Cervical Cancer Screening', 'Breast and Cervical Cancer Screening', 'Breast and Cervical Cancer Screening', 'Breast and Cervical Cancer Screening', 'Colorectal Cancer Screening', 'Colorectal Cancer Screening', 'Colorectal Cancer Screening', 'Colorectal Cancer Screening', 'Colorectal Cancer Screening', 'Colorectal Cancer Screening', 'Colorectal Cancer Screening', 'Colorectal Cancer Screening', 'Colorectal Cancer Screening', 'Colorectal Cancer Screening', 'Colorectal Cancer Screening', 'Colorectal Cancer Screening', 'Colorectal Cancer Screening', 'Tobacco Use', 'Tobacco Use', 'Tobacco Use', 'Tobacco Use', 'Lung Cancer Screening', 'Lung Cancer Screening', 'Lung Cancer Screening', 'Lung Cancer Screening', 'Lung Cancer Screening', 'Lung Cancer Screening', 'Alcohol Consumption', 'Alcohol Consumption', 'Alcohol Consumption', 'Alcohol Consumption', 'Immunization', 'Immunization', 'Immunization', 'Immunization', 'HIV/AIDS', 'HIV/AIDS', 'HIV/AIDS', 'Long-term COVID Ef fects', 'Long-term COVID Ef fects', 'Long-term COVID Ef fects', 'Pre-Diabetes', 'Pre-Diabetes', 'Diabetes', 'Diabetes', 'Diabetes', 'Diabetes', 'Diabetes', 'Diabetes', 'Diabetes', 'ME/CFS', 'ME/CFS', 'ME/CFS', 'Place of Flu Vaccination', 'HPV  Vaccination', 'HPV  Vaccination', 'Shingles Vaccination', 'COVID Vaccination', 'COVID Vaccination', 'COVID Vaccination', 'COVID Vaccination', 'COVID Vaccination', 'COVID Vaccination', 'Respiratory Health', 'Respiratory Health', 'Respiratory Health', 'Respiratory Health', 'Respiratory Health', 'Cancer Survivorship: Type of Cancer', 'Cancer Survivorship: Type of Cancer', 'Cancer Survivorship: Type of Cancer', 'Cancer Survivorship: Course of Treatment', 'Cancer Survivorship: Course of Treatment', 'Cancer Survivorship: Course of Treatment', 'Cancer Survivorship: Course of Treatment', 'Cancer Survivorship: Course of Treatment', 'Cancer Survivorship: Course of Treatment', 'Cancer Survivorship: Course of Treatment', 'Cancer Survivorship: Course of Treatment', 'Cancer Survivorship: Pain Management', 'Cancer Survivorship: Pain Management', 'Prostate Cancer Screening', 'Prostate Cancer Screening', 'Prostate Cancer Screening', 'Prostate Cancer Screening', 'Prostate Cancer Screening', 'Cognitive Dec ...

# %%
# Create a dictionary with the lists
variable_info = {
    'Label': labels,
    'Variable Name': sas_variable_names,
    'Question': questions,
    'Section': sections
}

# %%
var_info_df = pd.DataFrame(variable_info)

# %%
var_info_df.head()
# Out:
#              Label Variable Name         Question                Section
# 0  State FIPS Code        _STATE  State FIPS Code  Record Identification
# 1       File Month        FMONTH       File Month  Record Identification
# 2   Interview Date         IDATE   Interview Date  Record Identification
# 3  Interview Month        IMONTH  Interview Month  Record Identification
# 4    Interview Day          IDAY    Interview Day  Record Identification

# %% [markdown]
# ## Read, Overview data

# %%
#data = pd.read_parquet(PROCESSED_FILE_PATH_PARQUET)
data = pd.read_csv(PROCESSED_FILE_PATH_CSV)

# %%
# Create a dictionary with SAS variable names as keys and corresponding label/question as values
sas_variable_dict = dict(zip(sas_variable_names, zip(labels, questions)))

print(f'Number of variables in dictionary: {len(sas_variable_dict)}')

no_existing_cols = 0
# Loop through DataFrame columns
for col in data.columns:
    if col in sas_variable_dict:
        no_existing_cols += 1
        sas_variable_label, sas_variable_question = sas_variable_dict[col]
        print(f"{col}, {sas_variable_label}, {sas_variable_question}")

print(f'Number of existing columns in dataframe: {no_existing_cols}')
# Out:
# Number of variables in dictionary: 324
# _STATE, State FIPS Code, State FIPS Code
# FMONTH, File Month, File Month
# IDATE, Interview Date, Interview Date
# IMONTH, Interview Month, Interview Month
# IDAY, Interview Day, Interview Day
# IYEAR, Interview Year, Interview Year
# DISPCODE, Final Disposition, Final Disposition
# SEQNO, Annual Sequence Number, Annual Sequence Number
# _PSU, Primary Sampling Unit, Primary Sampling Unit (Equal to Annual Sequence Number)
# CTELENM1, Correct telephone number?, Is this     (phone number)     ?
# PVTRESD1, Private Residence?, Is this a private residence?   [READ ONL Y IF NECESSAR Y: � By private residence, we mean someplace like a house or apartment. � ]
# COLGHOUS, Do you live in college housing?, Do you live in college housing?
# STATERE1, Resident of State, Do you currently live in  ____(state)____?
# CELPHON1, Cellular Telephone, Is this a cell telephone?
# LADULT1, Are you 18 years of age or older?, Are you 18 years of age or older?
# COLGSEX1, Are you male or female?, Are you male or female?
# NUMADULT, Number of Adults in Household, I need to randomly select one adult who lives in your household to be interviewed. Excluding adults living away from home, such as students away at college, how many members of your household, including yourself, are 18 years of age or older?
# CRVCLHPV, Have an H.P .V. test and recent cervical cancer screening, At your most recent cervical cancer screening, did you have an H.P .V. test?
# HADHYST2, Had Hysterectomy, Have you had a hysterectomy?  (A  hysterectomy is an operation to remove the uterus (womb).)
# HADSIGM4, Ever Had Sigmoidoscopy/Colonoscopy, Colonoscopy and sigmoidoscopy are exams to check for colon cancer . Have you ever had either of these exams?
# COLNSIGM, Ever had a colonoscopy , sigmoidoscopy , or both, Have you had a colonoscopy , a sigmoidoscopy , or both?
# COLNTES1, How long since you had colonoscopy, How long has it been since your most recent colonoscopy?
# SIGMTES1, How long since you had sigmoidoscopy, How long has it been since your most recent sigmoidoscopy?
# LASTSIG4, Time Since Last Sigmoidoscopy/Colonoscopy, How long has it been since your most recent colonoscopy or sigmoidoscopy?
# COLNCNCR, Ever had any other kind of test for colorectal cancer, Have you ever had any other kind of test for colorectal cancer , such as virtual colonoscopy , CT colonography , blood stool test, FIT  DNA, or Cologuard test?
# VIRCOLO1, Ever had a virtual colonoscopy, A virtual colonoscopy uses a series of X-
# VCLNTES2, How long since you had  virtual colonoscopy, When was your most recent CT  colonography or virtual colonoscopy?
# SMALSTOL, Ever had stool test?, One stool test uses a special kit to obtain a small amount of stool at home and returns the kit to the doctor or the lab. Have you ever had this test?
# STOLTEST, How long since you had stool test?, How long has it been since you had this test?
# STOOLDN2, Ever had stool DNA  test?, Another stool test uses a special kit to obtain an entire bowel movement at home and returns the kit to a lab.   Have you ever had this test?
# BLDSTFIT, Was test part of Cologuard test?, Was the blood stool or FIT  (you reported earlier) conducted as part of a Cologuard test?
# SDNATES1, How long since you had stool DNA, How long has it been since you had this test?
# SMOKE100, Smoked at Least 100 Cigarettes, Have you smoked at least 100 cigarettes in your entire life?   [Note:  5 packs = 100 cigarettes]
# SMOKDAY2, Frequency of Days Now Smoking, Do you now smoke cigarettes every day , some days, or not at all?
# USENOW3, Use of Smokeless Tobacco Products, Do you currently use chewing tobacco, snuf f, or snus every day , some days, or not at all?  (Snus (Swedish for snuf f) is a moist smokeless tobacco, usually sold in small pouches that are placed under the lip against the gum.)
# ECIGNOW2, Do you now use e-cigarettes, or vaping products every day , some days, or not at all?, Would you say you have never used e-
# LCSFIRST, How old when you first started smoking?, How old were you when you first started to smoke cigarettes regularly
# LCSLAST, How old when you last smoked?, How old were you when you last smoked cigarettes regularly?
# LCSNUMCG, On average, how many cigarettes do you smoke each day?, On average, when you {smoke/smoked} regularly , about how many cigarettes {do/did} you usually smoke each day?
# LCSCTSC1, Did you have a CT  or CA T scan?, Have you ever had a CT  or CA T scan of your chest area?
# LCSSCNCR, Were any CT  or CA T scans done to check for lung cancer?, Were any of the CT  or CA T scans of your chest area done mainly to check or screen for lung cancer?
# LCSCTWHN, When did you have your most recent CT  or CA T scan?, When did you have your most recent CT  or CA T scan of your chest area mainly to check or screen for lung cancer?
# ALCDAY4, Days in past 30 had alcoholic beverage, During the past 30 days, how many days per week or per month did you have at least one drink of any alcoholic beverage?
# AVEDRNK3, Avg alcoholic drinks per day in past 30, One drink is equivalent to a 12-ounce beer , a 5-
# BCPREFER, What is your preferred birth control method?, If you could use any birth control method you wanted, what method would you use?
# RRCLASS3, How do other people usually classify you in this country?, How do other people usually classify you in this country? Would you say White, Black or African American, Hispanic or Latino, Asian, Native Hawaiian or Other Pacific Islander , American Indian or Alaska Native, or some other group?
# RRCOGNT2, How often do you think about your race?, How often do you think about your race? Would you say never , once a year , once a month, once a week, once a day , once an hour , or constantly?
# RRTREAT, Were you treated worse than, the same, or better than people of other races?, Within the past 12 months, do you feel that in general you were treated worse than, the same as, or better than people of other races?
# RRATWRK2, How do you feel you were treated at work compared to people of other races in past 12 months?, Within the past 12 months at work, do you feel you were treated worse than, the same as, or better than people of other races?
# RRHCARE4, When seeking health care past 12 months, was experience worse, same, better than people of other races?, Within the past 12 months when seeking health care, do you feel your experiences were worse than, the same as, or better than for people of other races?
# RRPHYSM2, Times past 30 days felt physical symptoms because of treatment due to your race, Within the past 30 days, have you experienced any physical symptoms, for example, a headache, an upset stomach, tensing of your muscles, or a pounding heart, as a result of how you were treated based on your race?
# QSTVER, Questionnaire Version Identifier, Questionnaire Version Identifier
# QSTLANG, Language identifier, Language identifier
# _METSTAT, Metropolitan Status, Metropolitan Status
# _URBSTAT, Urban/Rural Status, Urban/Rural Status
# MSCODE, Metropolitan Status Code, Metropolitan Status Code
# _STSTR, Sample Design Stratification Variable, Sample Design Stratification Variable  (Prior to 201 1:  _STSTR is a five digit number that combines the values for _ST ATE (first two characters), _GEOSTR (third and fourth character), and _DENSTR2 (final character).)
# _STRWT, Stratum weight, Stratum weight  (Number of records in a stratum (NRECSTR) divided by the number of records selected (NRECSEL).)
# _RAWRAKE, Raw weighting factor used in raking, Raw weighting factor used in raking  (Number of adults in the household (NUMADUL T, maximum of 5) divided by the imputed number of phones (_IMPNPH, maximum of 3).)
# _WT2RAKE, Design weight use in raking, Design weight used in raking  (Stratum weight (_STR WT) multiplied by the raw weighting factor (_RA WRAKE).)
# _IMPRACE, Imputed race/ethnicity value, Imputed race/ethnicity value  (This value is the reported race/ethnicity or an imputed race/ethnicity , if the respondent refused to give a race/ethnicity . The value of the imputed race/ethnicity will be the most common race/ethnicity response for that region of the state)
# _CHISPNC, Child Hispanic, Latino/a, or Spanish origin calculated variable, Child Hispanic, Latino/a, or Spanish origin calculated variable
# _CRACE2, Child Non-Hispanic Race including Multiracial, Child multiracial race categorization
# _CPRACE2, Preferred Child Race Categories, Preferred Child Race Categories
# CAGEG, Four level child age, Four level child age
# _CLLCPWT, Final child weight: Land-line and Cell-Phone data, Final child weight: Land-line and Cell-Phone data  (Raking derived weight)
# _DUALUSE, Dual Phone Use Categories, Dual Phone Use Categories
# _DUALCOR, Dual Phone Use Correction Factor, Dual phone use correction factor
# _LLCPWT2, Truncated design weight used in adult combined land line and cell phone raking, Truncated design weight used in adult combined land line and cell phone raking
# _LLCPWT, Final weight: Land-line and cell-phone data, Final weight assigned to each  respondent: Land-line and cell-phone data  (Raking derived weight)
# _RFHLTH, Adults with good or better health, Adults with good or better health
# _PHYS14D, Computed Physical Health Status, 3 level not good physical health status: 0 days, 1-13 days, 14-30 days
# _MENT14D, Computed Mental Health Status, 3 level not good mental health status: 0 days, 1-13 days, 14-30 days
# _HLTHPLN, Have any health insurance, Adults who had some form of health insurance
# _HCVU652, Respondents aged 18-64 with health insurance, Respondents aged 18-64 who have any form of health insurance
# _TOTINDA, Leisure Time Physical Activity Calculated Variable, Adults who reported doing physical activity or exercise during the past 30 days other than their regular job
# _EXTETH3, Adults aged 18+ that have had permanent teeth extracted, Adults aged 18+ who have had permanent teeth extracted
# _ALTETH3, Adults aged 65+ who have had all their natural teeth extracted, Adults aged 65+ who have had all their natural teeth extracted
# _DENVST3, Adults that have visited a dentist, dental hygenist or dental clinic within the past year, Adults who have visited a dentist, dental hygenist or dental clinic within the past year
# _MICHD, Ever had CHD or MI, Respondents that have ever reported having coronary heart disease (CHD) or myocardial infarction (MI)
# _LTASTH1, Lifetime Asthma Calculated Variable, Adults who have ever been told they have asthma
# _CASTHM1, Current Asthma Calculated Variable, Adults who have been told they currently have asthma
# _ASTHMS1, Computed Asthma Status, Computed asthma status
# _DRDXAR2, Respondents diagnosed with arthritis, Respondents who have had a doctor diagnose them as having some form of arthritis
# _PRACE2, Computed Preferred Race, Preferred race category
# _MRACE2, Calculated non-Hispanic Race including multiracial, Calculated multiracial race categorization
# _HISPANC, Hispanic, Latino/a, or Spanish origin calculated variable, Hispanic, Latino/a, or Spanish origin calculated variable
# _RACE1, Computed Race-Ethnicity grouping, Race/ethnicity categories
# _RACEG22, Create Computed Non-Hispanic Whites/All Others Race Categories Race/Ethnic Group Codes Used In Post-, White non-Hispanic race group
# _RACEGR4, Computed Five level race/ethnicity category ., Five-level race/ethnicity category
# _RACEPR1, Computed race groups used for internet prevalence tables, Computed race groups used for internet prevalence tables
# _SEX, Calculated sex variable, Calculated sex variable
# _AGEG5YR, Reported age in five-year age categories calculated variable, Fourteen-level age category
# _AGE65YR, Reported age in two age groups calculated variable, Two-level age category
# _AGE80, Imputed Age value collapsed above 80, Imputed Age value collapsed above 80
# _AGE_G, Imputed age in six groups, Six-level imputed age category
# HTIN4, Computed Height in Inches, Reported height in inches
# HTM4, Computed Height in Meters, Reported height in meters
# WTKG3, Computed Weight in Kilograms, Reported weight in kilograms
# _BMI5, Computed body mass index, Body Mass Index (BMI)
# _BMI5CAT, Computed body mass index categories, Four -categories of Body Mass Index (BMI)
# _RFBMI5, Overweight or obese calculated variable, Adults who have a body mass index greater than 25.00 (Overweight or Obese)
# _CHLDCNT, Computed number of children in household, Number of children in household
# _EDUCAG, Computed level of education completed categories, Level of education completed
# _INCOMG1, Computed income categories, Income categories
# _RFMAM22, Women respondents aged 40+ who have had a mammogram in the past two years, Women respondents aged 40+ who have had a mammogram in the past two years
# _MAM5023, Women respondents aged 50-74 that have had a mammogram in the past two years, Women respondents aged 50-74 who have had a mammogram in the past two years
# _HADCOLN, Had colonoscopy calculated variable, Had colonoscopy calculated variable
# _CLNSCP1, Respondents aged 45-75 who have had a colonoscopy within the past ten years, Respondents aged 45-75 who have had a colonoscopy within the past ten years
# _HADSIGM, Had sigmoidoscopy calculated variable, Had sigmoidoscopy calculated variable
# _SGMSCP1, Respondents aged 45-75 who have had a sigmoidoscopy within the past five years, Respondents aged 45-75 who have had a sigmoidoscopy within the past five years
# _SGMS101, Respondents aged 45-75 who have had a sigmoidoscopy within the past ten years, Respondents aged 45-75 who have had a sigmoidoscopy within the past ten years
# _RFBLDS5, Respondents aged 45-75 who have had a stool test within the past year, Respondents aged 45-75 who have had a stool test within the past year
# _STOLDN1, Respondents aged 45-75 who have had a stool DNA  test within the past three years, Respondents aged 45-75 who have had a stool DNA  test within the past three years
# _VIRCOL1, Respondents aged 45-75 who have had a virtual colonoscopy within the past five years, Respondents aged 45-75 who have had a virtual colonoscopy within the past five years
# _SBONTI1, Respondents aged 45-, Respondents aged 45-
# _CRCREC2, Respondents aged 45-75 who have fully met the USPSTF recommendations, Respondents aged 45-75 who have fully met the USPSTF recommendations
# _SMOKER3, Computed Smoking Status, Four -level smoker status:  Everyday smoker , Someday smoker , Former smoker , Non-smoker
# _RFSMOK3, Current Smoking Calculated Variable, Adults who are current smokers
# _CURECI2, Current E-cigarette User Calculated Variable, Adults who are current e-cigarette users
# _YRSSMOK, Number of years smoked cigarettes, Number of years respondent smoked cigarettes
# _PACKDAY, Number of packs of cigarettes smoked per day, Number of packs of cigarettes smoked per day
# _PACKYRS, Years smoked reported packs per day, Number of years smoked reported number of packs per day
# _YRSQUIT, Number of years since quit smoking cigarettes, Number of years since quit smoking cigarettes
# _SMOKGRP, Smoking Group, Smoking Group
# _LCSREC, Lung cancer screening recommendation status, Lung cancer screening recommendation status
# DRNKANY6, Drink any alcoholic beverages in past 30 days, Adults who reported having had at least one drink of alcohol in the past 30 days.
# DROCDY4_, Computed drink-occasions-per -day, Drink-occasions-per -day
# _RFBING6, Binge Drinking Calculated Variable, Binge drinkers (males having five or more drinks on one occasion, females having four or more drinks on one occasion)
# _DRNKWK2, Computed number of drinks of alcohol beverages per week, Calculated total number of alcoholic beverages consumed per week
# _RFDRHV8, Heavy Alcohol Consumption  Calculated Variable, Heavy drinkers (adult men having more than 14 drinks per week and adult women having more than 7 drinks per week)
# _FLSHOT7, Flu Shot Calculated Variable, Adults aged 65+ who have had a flu shot within the past year
# _PNEUMO3, Pneumonia Vaccination Calculated Variable, Adults aged 65+ who have ever had a pneumonia vaccination
# _AIDTST4, Ever been tested for HIV  calculated variable, Adults who have ever been tested for HIV
# Number of existing columns in dataframe: 324

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445132 entries, 0 to 445131
# Columns: 328 entries, _STATE to _AIDTST4
# dtypes: float64(323), object(5)
# memory usage: 1.1+ GB

# %% [markdown]
# The dataset has:
# - 445132 samples/instances
# - 328 variables
# - 323 numerical variables. Categorical variables can be converted to numerical variables, e.g Yes=1, No=0
# - 5 variables as strings

# %%
data.head()
# Out:
#    _STATE  FMONTH     IDATE IMONTH IDAY IYEAR  DISPCODE       SEQNO  \
# 0     1.0     1.0  02032022     02   03  2022    1100.0  2022000001
# 1     1.0     1.0  02042022     02   04  2022    1100.0  2022000002
# 2     1.0     1.0  02022022     02   02  2022    1100.0  2022000003
# 3     1.0     1.0  02032022     02   03  2022    1100.0  2022000004
# 4     1.0     1.0  02022022     02   02  2022    1100.0  2022000005
#
#            _PSU  CTELENM1  ...  _SMOKGRP  _LCSREC  DRNKANY6      DROCDY4_  \
# 0  2.022000e+09       1.0  ...       4.0      NaN       2.0  5.397605e-79
# 1  2.022000e+09       1.0  ...       4.0      NaN       2.0  5.397605e-79
# 2  2.022000e+09       1.0  ...       4.0      NaN       2.0  5.397605e-79
# 3  2.022000e+09       1.0  ...       3.0      2.0       2.0  5.397605e-79
# 4  2.022000e+09       1.0  ...       4.0      NaN       1.0  1.000000e+01
#
#    _RFBING6      _DRNKWK2  _RFDRHV8  _FLSHOT7  _PNEUMO3  _AIDTST4
# 0       1.0  5.397605e-79       1.0       1.0       2.0       2.0
# 1       1.0  5.397605e-79       1.0       2.0       2.0       2.0
# 2       1.0  5.397605e-79       1.0       NaN       NaN       2.0
# 3       1.0  5.397605e-79       1.0       9.0       9.0       2.0
# 4       1.0  1.400000e+02       1.0       NaN       NaN       2.0
#
# [5 rows x 328 columns]

# %% [markdown]
# ## Extracting the list of variables

# %%
# These variable names are the ones used in the Kaggle dataset. 
"""
NEW_VAR_NAMES = [
    "State",
    "Sex",
    "General_Health",
    "Physical_Health_Days",
    "Mental_Health_Days",
    "Last_Checkup_Time",
    "Physical_Activities",
    "Sleep_Hours",
    "Removed_Teeth",
    "Had_Heart_Attack",
    "Had_Angina",
    "Had_Stroke",
    "Had_Asthma",
    "Had_Skin_Cancer",
    "Had_COPD",
    "Had_Depressive_Disorder",
    "Had_Kidney_Disease",
    "Had_Arthritis",
    "Had_Diabetes",
    "Deaf_Or_Hard_Of_Hearing",
    "Blind_Or_Vision_Difficulty",
    "Difficulty_Concentrating",
    "Difficulty_Walking",
    "Difficulty_Dressing_Bathing",
    "Difficulty_Errands",
    "Smoker_Status",
    "E_Cigarette_Usage",
    "Chest_Scan",
    "Race_Ethnicity_Category",
    "Age_Category",
    "Height_In_Meters",
    "Weight_In_Kilograms",
    "BMI",
    "Alcohol_Drinkers",
    "HIV_Testing",
    "Flu_Vax_Last_12",
    "Pneumo_Vax_Ever",
    "Tetanus_Last_10Tdap",
    "High_Risk_Last_Year",
    "Covid_Pos"
]
"""

# %%
# These variable names are identical as the ones above but, instead of using 'Had_Heart_Attck', we use 'Had_CHD_MI'.
NEW_VAR_NAMES = [
    "State",
    "Sex",
    "General_Health",
    "Physical_Health_Days",
    "Mental_Health_Days",
    "Last_Checkup_Time",
    "Physical_Activities",
    "Sleep_Hours",
    "Removed_Teeth",
    "Had_CHD_MI",
    "Had_Stroke",
    "Had_Asthma",
    "Had_Skin_Cancer",
    "Had_COPD",
    "Had_Depressive_Disorder",
    "Had_Kidney_Disease",
    "Had_Arthritis",
    "Had_Diabetes",
    "Deaf_Or_Hard_Of_Hearing",
    "Blind_Or_Vision_Difficulty",
    "Difficulty_Concentrating",
    "Difficulty_Walking",
    "Difficulty_Dressing_Bathing",
    "Difficulty_Errands",
    "Smoker_Status",
    "E_Cigarette_Usage",
    "Chest_Scan",
    "Race_Ethnicity_Category",
    "Age_Category",
    "Height_In_Meters",
    "Weight_In_Kilograms",
    "BMI",
    "Alcohol_Drinkers",
    "HIV_Testing",
    "Flu_Vax_Last_12",
    "Pneumo_Vax_Ever",
    "Tetanus_Last_10Tdap",
    "High_Risk_Last_Year",
    "Covid_Pos"
]

# %%
variable_list_df = pd.read_csv(VARIABLE_LIST_PATH, sep=' - ', header=None, names=['Variable', 'Description'])
# Out:
# /tmp/ipykernel_4668/187747097.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   variable_list_df = pd.read_csv(VARIABLE_LIST_PATH, sep=' - ', header=None, names=['Variable', 'Description'])

# %%
variable_list_df
# Out:
#     Variable                                        Description
# 0     _STATE                                    State FIPS Code
# 1     SEXVAR                                  Sex of Respondent
# 2    GENHLTH      Would you say that in general your health is:
# 3   PHYSHLTH  Now thinking about your physical health, which...
# 4   MENTHLTH  Now thinking about your mental health, which i...
# 5   CHECKUP1  About how long has it been since you last visi...
# 6   EXERANY2  During the past month, other than your regular...
# 7   SLEPTIM1  On average, how many hours of sleep do you get...
# 8   RMVTETH4  Not including teeth lost for injury or orthodo...
# 9   CVDSTRK3                    (Ever told) (you had) a stroke.
# 10   ASTHMA3                      (Ever told) (you had) asthma?
# 11  CHCSCNC1  (Ever told) (you had) skin cancer that is not ...
# 12  CHCCOPD3  (Ever told) (you had) C.O.P.D. (chronic obstru...
# 13  ADDEPEV3  (Ever told) (you had) a depressive disorder (i...
# 14  CHCKDNY2  Not including kidney stones, bladder infection...
# 15  HAVARTH4  (Ever told) (you had) some form of arthritis, ...
# 16  DIABETE4                    (Ever told) (you had) diabetes?
# 17      DEAF  Are you deaf or do you have serious difficulty...
# 18     BLIND  Are you blind or do you have serious difficult...
# 19    DECIDE  Because of a physical, mental, or emotional co...
# 20  DIFFWALK  Do you have serious difficulty walking or clim...
# 21  DIFFDRES        Do you have difficulty dressing or bathing?
# 22  DIFFALON  Because of a physical, mental, or emotional co...
# 23  _SMOKER3  Four-level smoker status:  Everyday smoker, So...
# 24  ECIGNOW2  Would you say you have never used e-cigarettes...
# 25  LCSCTSC1  Have you ever had a CT or CAT scan of your che...
# 26  _RACEGR4                 Five-level race/ethnicity category
# 27  _AGEG5YR                        Fourteen-level age category
# 28      HTM4                          Reported height in meters
# 29     WTKG3                       Reported weight in kilograms
# 30     _BMI5                              Body Mass Index (BMI)
# 31    _MICHD                                 Ever had CHD or MI
# 32  DRNKANY6  Adults who reported having had at least one dr...
# 33  _AIDTST4           Adults who have ever been tested for HIV
# 34  FLUSHOT7  During the past 12 months, have you had either...
# 35  PNEUVAC4  Have you ever had a pneumonia shot also known ...
# 36  TETANUS1  Have you received a tetanus shot in the past 1...
# 37  HIVRISK5  You have injected any drug other than those pr...
# 38  COVIDPOS  Has a doctor, nurse, or other health professio...

# %%
variable_list = variable_list_df['Variable'].to_numpy()

# %%
variable_list
# Out:
# array(['_STATE', 'SEXVAR', 'GENHLTH', 'PHYSHLTH', 'MENTHLTH', 'CHECKUP1',
#        'EXERANY2', 'SLEPTIM1', 'RMVTETH4', 'CVDSTRK3', 'ASTHMA3',
#        'CHCSCNC1', 'CHCCOPD3', 'ADDEPEV3', 'CHCKDNY2', 'HAVARTH4',
#        'DIABETE4', 'DEAF', 'BLIND', 'DECIDE', 'DIFFWALK', 'DIFFDRES',
#        'DIFFALON', '_SMOKER3', 'ECIGNOW2', 'LCSCTSC1', '_RACEGR4',
#        '_AGEG5YR', 'HTM4', 'WTKG3', '_BMI5', '_MICHD', 'DRNKANY6',
#        '_AIDTST4', 'FLUSHOT7', 'PNEUVAC4', 'TETANUS1', 'HIVRISK5',
#        'COVIDPOS'], dtype=object)

# %%
# Check if all column names are present in the DataFrame
if all(col in data.columns for col in variable_list):
    print("All column names exist in the DataFrame.")
else:
    # Identify which column names are missing
    missing_columns = [col for col in variable_list if col not in data.columns]
    print(f"The following column(s) are missing: {missing_columns}")
# Out:
# All column names exist in the DataFrame.

# %%
data = data[variable_list]

# %%
data.shape
# Out:
# (445132, 39)

# %%
data.dropna().shape
# Out:
# (364044, 39)

# %%
data.columns = NEW_VAR_NAMES

# %%
data['Had'].value_counts()
# Out:
# Had_Diabetes
# 2.0    385539
# 1.0     38946
# 7.0      1246
# 9.0       757
# Name: count, dtype: int64

# %%
STATE = {
    1: "Alabama",
    2: "Alaska",
    4: "Arizona",
    5: "Arkansas",
    6: "California",
    8: "Colorado",
    9: "Connecticut",
    10: "Delaware",
    11: "District of Columbia",
    12: "Florida",
    13: "Georgia",
    15: "Hawaii",
    16: "Idaho",
    17: "Illinois",
    18: "Indiana",
    19: "Iowa",
    20: "Kansas",
    21: "Kentucky",
    22: "Louisiana",
    23: "Maine",
    24: "Maryland",
    25: "Massachusetts",
    26: "Michigan",
    27: "Minnesota",
    28: "Mississippi",
    29: "Missouri",
    30: "Montana",
    31: "Nebraska",
    32: "Nevada",
    33: "New Hampshire",
    34: "New Jersey",
    35: "New Mexico",
    36: "New York",
    37: "North Carolina",
    38: "North Dakota",
    39: "Ohio",
    40: "Oklahoma",
    41: "Oregon",
    42: "Pennsylvania",
    44: "Rhode Island",
    45: "South Carolina",
    46: "South Dakota",
    47: "Tennessee",
    48: "Texas",
    49: "Utah",
    50: "Vermont",
    51: "Virginia",
    53: "Washington",
    54: "West Virginia",
    55: "Wisconsin",
    56: "Wyoming",
    66: "Guam",
    72: "Puerto Rico",
    78: "Virgin Islands"
}

SEX = {1: 'Male', 2: 'Female'}

GEN_HEALTH = {
    1: "Excellent",
    2: "Very good",
    3: "Good",
    4: "Fair",
    5: "Poor"
}

PHYS_MEN_HEALTH = {77: np.nan,
               88: 0,
               99: np.nan
                  }

LAST_CHECKUP = {
    1: "Within past year (anytime less than 12 months ago)",
    2: "Within past 2 years (1 year but less than 2 years ago)",
    3: "Within past 5 years (2 years but less than 5 years ago)",
    4: "5 or more years ago"
}

YES_NO_QUESTIONS = {1: 'Yes', 2: 'No'}

SLEEP_TIME = lambda x: np.where(x > 24, np.nan, x)

TEETH_REMOVED = {
    1: "1 to 5",
    2: "6 or more, but not all",
    3: "All",
    8: "None of them"
}

DIABETES = {
    1: "Yes",
    2: "Yes, but only during pregnancy (female)",
    3: "No",
    4: "No, pre-diabetes or borderline diabetes",
}

SMOKER_STATUS = {
    1: "Current smoker - now smokes every day",
    2: "Current smoker - now smokes some days",
    3: "Former smoker",
    4: "Never smoked"
}

ECIGARETTES = {
    1: "Never used e-cigarettes in my entire life",
    2: "Use them every day",
    3: "Use them some days",
    4: "Not at all (right now)"
}

RACE = {
    1: "White only, Non-Hispanic",
    2: "Black only, Non-Hispanic",
    3: "Other race only, Non-Hispanic",
    4: "Multiracial, Non-Hispanic",
    5: "Hispanic"
}

AGE_CATEGORY = {
    1: "Age 18 to 24",
    2: "Age 25 to 29",
    3: "Age 30 to 34",
    4: "Age 35 to 39",
    5: "Age 40 to 44",
    6: "Age 45 to 49",
    7: "Age 50 to 54",
    8: "Age 55 to 59",
    9: "Age 60 to 64",
    10: "Age 65 to 69",
    11: "Age 70 to 74",
    12: "Age 75 to 79",
    13: "Age 80 or older"
}

TETANUS = {
    1: "Yes, received Tdap",
    2: "Yes, received tetanus shot, but not Tdap",
    3: "Yes, received tetanus shot but not sure what type",
    4: "No, did not receive any tetanus shot in the past 10 years",
}

COVID = {
    1: "Yes",
    2: "No",
    3: "Tested positive using home test without a health professional"
}

# %%
data_copy = data.copy()

# %%
data_copy['State'] = data_copy['State'].map(STATE)
data_copy['Sex'] = data_copy['Sex'].map(SEX)
data_copy['General_Health'] = data_copy['General_Health'].map(GEN_HEALTH)
data_copy['Physical_Health_Days'] = data_copy['Physical_Health_Days'].replace(PHYS_MEN_HEALTH)
data_copy['Mental_Health_Days'] = data_copy['Mental_Health_Days'].replace(PHYS_MEN_HEALTH)
data_copy['Last_Checkup_Time'] = data_copy['Last_Checkup_Time'].map(LAST_CHECKUP)
data_copy['Physical_Activities'] = data_copy['Physical_Activities'].map(YES_NO_QUESTIONS)
data_copy['Sleep_Hours'] = data_copy['Sleep_Hours'].apply(SLEEP_TIME)
data_copy['Removed_Teeth'] = data_copy['Removed_Teeth'].map(TEETH_REMOVED)
#data_copy['Had_Heart_Attack'] = data_copy['Had_Heart_Attack'].map(YES_NO_QUESTIONS)
data_copy['Had_CHD_MI'] = data_copy['Had_CHD_MI'].map(YES_NO_QUESTIONS)
data_copy['Had_Angina'] = data_copy['Had_Angina'].map(YES_NO_QUESTIONS)
data_copy['Had_Stroke'] = data_copy['Had_Stroke'].map(YES_NO_QUESTIONS)
data_copy['Had_Asthma'] = data_copy['Had_Asthma'].map(YES_NO_QUESTIONS)
data_copy['Had_Skin_Cancer'] = data_copy['Had_Skin_Cancer'].map(YES_NO_QUESTIONS)
data_copy['Had_COPD'] = data_copy['Had_COPD'].map(YES_NO_QUESTIONS)
data_copy['Had_Depressive_Disorder'] = data_copy['Had_Depressive_Disorder'].map(YES_NO_QUESTIONS)
data_copy['Had_Kidney_Disease'] = data_copy['Had_Kidney_Disease'].map(YES_NO_QUESTIONS)
data_copy['Had_Arthritis'] = data_copy['Had_Arthritis'].map(YES_NO_QUESTIONS)
data_copy['Had_Diabetes'] = data_copy['Had_Diabetes'].map(DIABETES)
data_copy['Deaf_Or_Hard_Of_Hearing'] = data_copy['Deaf_Or_Hard_Of_Hearing'].map(YES_NO_QUESTIONS)
data_copy['Blind_Or_Vision_Difficulty'] = data_copy['Blind_Or_Vision_Difficulty'].map(YES_NO_QUESTIONS)
data_copy['Difficulty_Concentrating'] = data_copy['Difficulty_Concentrating'].map(YES_NO_QUESTIONS)
data_copy['Difficulty_Walking'] = data_copy['Difficulty_Walking'].map(YES_NO_QUESTIONS)
data_copy['Difficulty_Dressing_Bathing'] = data_copy['Difficulty_Dressing_Bathing'].map(YES_NO_QUESTIONS)
data_copy['Difficulty_Errands'] = data_copy['Difficulty_Errands'].map(YES_NO_QUESTIONS)
data_copy['Smoker_Status'] = data_copy['Smoker_Status'].map(SMOKER_STATUS)
data_copy['E_Cigarette_Usage'] = data_copy['E_Cigarette_Usage'].map(ECIGARETTES)
data_copy['Chest_Scan'] = data_copy['Chest_Scan'].map(YES_NO_QUESTIONS)
data_copy['Race_Ethnicity_Category'] = data_copy['Race_Ethnicity_Category'].map(RACE)
data_copy['Age_Category'] = data_copy['Age_Category'].map(AGE_CATEGORY)
data_copy['Height_In_Meters'] = data_copy['Height_In_Meters'] / 100
data_copy['Weight_In_Kilograms'] = data_copy['Weight_In_Kilograms'] / 100
data_copy['BMI'] = data_copy['BMI'] / 100
data_copy['Alcohol_Drinkers'] = data_copy['Alcohol_Drinkers'].map(YES_NO_QUESTIONS)
data_copy['HIV_Testing'] = data_copy['HIV_Testing'].map(YES_NO_QUESTIONS)
data_copy['Flu_Vax_Last_12'] = data_copy['Flu_Vax_Last_12'].map(YES_NO_QUESTIONS)
data_copy['Pneumo_Vax_Ever'] = data_copy['Pneumo_Vax_Ever'].map(YES_NO_QUESTIONS)
data_copy['Tetanus_Last_10Tdap'] = data_copy['Tetanus_Last_10Tdap'].map(TETANUS)
data_copy['High_Risk_Last_Year'] = data_copy['High_Risk_Last_Year'].map(YES_NO_QUESTIONS)
data_copy['Covid_Pos'] = data_copy['Covid_Pos'].map(COVID)

# %%
data_copy.shape
# Out:
# (445132, 40)

# %%
data.shape
# Out:
# (445132, 40)

# %%
# Create a DataFrame to display side by side
comparison_df = pd.DataFrame({
    'Original Data': data.isna().sum(),
    'New Data': data_copy.isna().sum()
})

# %%
# Display the comparison DataFrame
print(comparison_df)
# Out:
#                              Original Data  New Data
# State                                    0         0
# Sex                                      0         0
# General_Health                           3      1198
# Physical_Health_Days                     5     10927
# Mental_Health_Days                       3      9067
# Last_Checkup_Time                        3      8308
# Physical_Activities                      2      1093
# Sleep_Hours                              3      5453
# Removed_Teeth                         1363     11360
# Had_CHD_MI                               2      4405
# Had_Angina                               2      1557
# Had_Stroke                               2      1773
# Had_Asthma                               2      3143
# Had_Skin_Cancer                          2      2219
# Had_COPD                                 7      2812
# Had_Depressive_Disorder                  2      1926
# Had_Kidney_Disease                       3      2633
# Had_Arthritis                            3    380138
# Had_Diabetes                         18644     20647
# Deaf_Or_Hard_Of_Hearing              19855     21564
# Blind_Or_Vision_Difficulty           20986     24240
# Difficulty_Concentrating             22155     24012
# Difficulty_Walking                   22879     23915
# Difficulty_Dressing_Bathing          23942     25656
# Difficulty_Errands                       0    395191
# Smoker_Status                        33579     35660
# E_Cigarette_Usage                    38210     56046
# Chest_Scan                               2     89265
# Race_Ethnicity_Category                  0    311926
# Age_Category                         28652    445132
# Height_In_Meters                     42078     42078
# Weight_In_Kilograms                  48806     48806
# BMI                                   5021      5021
# Alcohol_Drinkers                         0     46574
# HIV_Testing                          46235     66127
# Flu_Vax_Last_12                      43593     47121
# Pneumo_Vax_Ever                      44732     77040
# Tetanus_Last_10Tdap                  45383     82516
# High_Risk_Last_Year                  48461     50623
# Covid_Pos                            49235     50764

# %%
data_copy.dropna().shape[0]
# Out:
# 0

# %%
data.dropna().shape[0]
# Out:
# 364044

# %%
def describe_df(df: pd.DataFrame):
    print(f"The dataset contains {df.shape[1]} columns and {len(df)} rows")

    for col in df.columns:
        col_dtype = df[col].dtype
        
        print(f"\nColumn: {col} ({col_dtype})")
        if col_dtype == 'object':
            print(f"--- Percentage of NaNs: {df[col].isna().sum() / len(df[col]) * 100}")
            print(f"--- Unique values:\n {df[col].unique()}")
        else:
            print(f"--- Summary statistics:\n {df[col].describe()}")

# %%
describe_df(data_copy)
# Out:
# The dataset contains 40 columns and 445132 rows
#
# Column: State (object)
# --- Percentage of NaNs: 0.0
# --- Unique values:
#  ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'District of Columbia' 'Florida' 'Georgia'
#  'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky'
#  'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan' 'Minnesota'
#  'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada' 'New Hampshire'
#  'New Jersey' 'New Mexico' 'New York' 'North Carolina' 'North Dakota'
#  'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina'
#  'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virginia'
#  'Washington' 'West Virginia' 'Wisconsin' 'Wyoming' 'Guam' 'Puerto Rico'
#  'Virgin Islands']
#
# Column: Sex (object)
# --- Percentage of NaNs: 0.0
# --- Unique values:
#  ['Female' 'Male']
#
# Column: General_Health (object)
# --- Percentage of NaNs: 0.26913365024307395
# --- Unique values:
#  ['Very good' 'Excellent' 'Fair' 'Poor' 'Good' nan]
#
# Column: Physical_Health_Days (float64)
# --- Summary statistics:
#  count    434205.000000
# mean          4.347919
# std           8.688912
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           3.000000
# max          30.000000
# Name: Physical_Health_Days, dtype: float64
#
# Column: Mental_Health_Days (float64)
# --- Summary statistics:
#  count    436065.000000
# mean          4.382649
# std           8.387475
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           5.000000
# max          30.000000
# Name: Mental_Health_Days, dtype: float64
#
# Column: Last_Checkup_Time (object)
# --- Percentage of NaNs: 1.8664126596155746
# --- Unique values:
#  ['Within past year (anytime less than 12 months ago)' nan
#  'Within past 2 years (1 year but less than 2 years ago)'
#  'Within past 5 years (2 years but less than 5 years ago)'
#  '5 or more years ago']
#
# Column: Physical_Activities (object)
# --- Percentage of NaNs: 0.24554514166584296
# --- Unique values:
#  ['No' 'Yes' nan]
#
# Column: Sleep_Hours (float64)
# --- Summary statistics:
#  count    439679.000000
# mean          7.022983
# std           1.502425
# min           1.000000
# 25%           6.000000
# 50%           7.000000
# 75%           8.000000
# max          24.000000
# Name: Sleep_Hours, dtype: float64
#
# Column: Removed_Teeth (object)
# --- Percentage of NaNs: 2.5520519755937565
# --- Unique values:
#  [nan 'None of them' '1 to 5' '6 or more, but not all' 'All']
#
# Column: Had_CHD_MI (object)
# --- Percentage of NaNs: 0.9895940979305015
# --- Unique values:
#  ['No' 'Yes' nan]
#
# Column: Had_Angina (object)
# --- Percentage of NaNs: 0.34978388433094004
# --- Unique values:
#  ['No' 'Yes' nan]
#
# Column: Had_Stroke (object)
# --- Percentage of NaNs: 0.3983088162612438
# --- Unique values:
#  ['No' 'Yes' nan]
#
# Column: Had_Asthma (object)
# --- Percentage of NaNs: 0.7060826900784486
# --- Unique values:
#  ['No' 'Yes' nan]
#
# Column: Had_Skin_Cancer (object)
# --- Percentage of NaNs: 0.49850381459881565
# --- Unique values:
#  ['No' 'Yes' nan]
#
# Column: Had_COPD (object)
# --- Percentage of NaNs: 0.6317227249445109
# --- Unique values:
#  ['No' 'Yes' nan]
#
# Column: Had_Depressive_Disorder (object)
# --- Percentage of NaNs: 0.43268064304520903
# --- Unique values:
#  ['No' 'Yes' nan]
#
# Column: Had_Kidney_Disease (object)
# --- Percentage of NaNs: 0.5915099341318979
# --- Unique values:
#  ['No' 'Yes' nan]
#
# Column: Had_Arthritis (object)
# --- Percentage of NaNs: 85.39893784315665
# --- Unique values:
#  ['Yes' nan 'No']
#
# Column: Had_Diabetes (object)
# --- Percentage of NaNs: 4.63839939613418
# --- Unique values:
#  ['Yes, but only during pregnancy (female)' nan 'Yes']
#
# Column: Deaf_Or_Hard_Of_Hearing (object)
# --- Percentage of NaNs: 4.8444057043753315
# --- Unique values:
#  ['No' 'Yes' nan]
#
# Column: Blind_Or_Vision_Difficulty (object)
# --- Percentage of NaNs: 5.4455756944007625
# --- Unique values:
#  ['No' nan 'Yes']
#
# Column: Difficulty_Concentrating (object)
# --- Percentage of NaNs: 5.394354932918775
# --- Unique values:
#  ['No' 'Yes' nan]
#
# Column: Difficulty_Walking (object)
# --- Percentage of NaNs: 5.372563644042666
# --- Unique values:
#  ['No' nan 'Yes']
#
# Column: Difficulty_Dressing_Bathing (object)
# --- Percentage of NaNs: 5.7636835814994205
# --- Unique values:
#  ['No' 'Yes' nan]
#
# Column: Difficulty_Errands (object)
# --- Percentage of NaNs: 88.780631363281
# --- Unique values:
#  [nan 'No' 'Yes']
#
# Column: Smoker_Status (object)
# --- Percentage of NaNs: 8.011106817752935
# --- Unique values:
#  ['Never smoked' 'Current smoker - now smokes every day' nan
#  'Current smoker - now smokes some days' 'Former smoker']
#
# Column: E_Cigarette_Usage (object)
# --- Percentage of NaNs: 12.590871921138
# --- Unique values:
#  ['Use them every day' 'Never used e-cigarettes in my entire life' nan]
#
# Column: Chest_Scan (object)
# --- Percentage of NaNs: 20.053602077585975
# --- Unique values:
#  ['Yes' 'No' nan]
#
# Column: Race_Ethnicity_Category (object)
# --- Percentage of NaNs: 70.0749440615368
# --- Unique values:
#  [nan 'Hispanic' 'Multiracial, Non-Hispanic' 'Black only, Non-Hispanic'
#  'Other race only, Non-Hispanic' 'White only, Non-Hispanic']
#
# Column: Age_Category (object)
# --- Percentage of NaNs: 100.0
# --- Unique values:
#  [nan]
#
# Column: Height_In_Meters (float64)
# --- Summary statistics:
#  count    403054.000000
# mean         83.074470
# std          21.448173
# min          22.680000
# 25%          68.040000
# 50%          80.740000
# 75%          95.250000
# max         292.570000
# Name: Height_In_Meters, dtype: float64
#
# Column: Weight_In_Kilograms (float64)
# --- Summary statistics:
#  count    396326.000000
# mean         28.529842
# std           6.554889
# min          12.020000
# 25%          24.130000
# 50%          27.440000
# 75%          31.750000
# max          99.640000
# Name: Weight_In_Kilograms, dtype: float64
#
# Column: BMI (float64)
# --- Summary statistics:
#  count    440111.000000
# mean          0.019097
# std           0.002866
# min           0.010000
# 25%           0.020000
# 50%           0.020000
# 75%           0.020000
# max           0.020000
# Name: BMI, dtype: float64
#
# Column: Alcohol_Drinkers (object)
# --- Percentage of NaNs: 10.462963795009122
# --- Unique values:
#  ['No' 'Yes' nan]
#
# Column: HIV_Testing (object)
# --- Percentage of NaNs: 14.855593397014818
# --- Unique values:
#  ['No' 'Yes' nan]
#
# Column: Flu_Vax_Last_12 (object)
# --- Percentage of NaNs: 10.585848692073363
# --- Unique values:
#  ['Yes' 'No' nan]
#
# Column: Pneumo_Vax_Ever (object)
# --- Percentage of NaNs: 17.30722572180836
# --- Unique values:
#  ['No' 'Yes' nan]
#
# Column: Tetanus_Last_10Tdap (object)
# --- Percentage of NaNs: 18.53742260722662
# --- Unique values:
#  ['Yes, received tetanus shot but not sure what type'
#  'No, did not receive any tetanus shot in the past 10 years' nan
#  'Yes, received Tdap' 'Yes, received tetanus shot, but not Tdap']
#
# Column: High_Risk_Last_Year (object)
# --- Percentage of NaNs: 11.372581616239676
# --- Unique values:
#  ['No' nan 'Yes']
#
# Column: Covid_Pos (object)
# --- Percentage of NaNs: 11.404257613471959
# --- Unique values:
#  ['No' 'Yes' nan
#  'Tested positive using home test without a health professional']

# %%
data_copy.dropna().to_csv(FINAL_FILE, index=False)
